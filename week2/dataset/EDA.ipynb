# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# # Read and view all datasets

# %%
cab_data = pd.read_csv('Cab_Data.csv')
city = pd.read_csv('City.csv')
customer_ID = pd.read_csv('Customer_ID.csv')
transaction_ID = pd.read_csv('Transaction_ID.csv')

# %%
cab_data
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %%
city
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
city.describe()
# Out:
#                City   Population      Users
# count            20           20         20
# unique           20           20         20
# top     NEW YORK NY   8,405,837    302,149
# freq              1            1          1

# %%
customer_ID
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
customer_ID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
customer_ID.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
transaction_ID
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %% [markdown]
# ## Combining all datasets into single

# %%
data = pd.merge(transaction_ID, cab_data, how='right', on='Transaction ID')
data
# Out:
#         Transaction ID  Customer ID Payment_Mode  Date of Travel     Company  \
# 0             10000011        29290         Card           42377    Pink Cab
# 1             10000012        27703         Card           42375    Pink Cab
# 2             10000013        28712         Cash           42371    Pink Cab
# 3             10000014        28020         Cash           42376    Pink Cab
# 4             10000015        27182         Card           42372    Pink Cab
# ...                ...          ...          ...             ...         ...
# 359387        10440101        52392         Cash           43108  Yellow Cab
# 359388        10440104        53286         Cash           43104  Yellow Cab
# 359389        10440105        52265         Cash           43105  Yellow Cab
# 359390        10440106        52175         Card           43105  Yellow Cab
# 359391        10440107        52917         Card           43102  Yellow Cab
#
# ...

# %%
data1 = pd.merge(data, customer_ID, how='inner', on='Customer ID')
data1
# Out:
#         Transaction ID  Customer ID Payment_Mode  Date of Travel     Company  \
# 0             10000011        29290         Card           42377    Pink Cab
# 1             10351127        29290         Cash           43302  Yellow Cab
# 2             10412921        29290         Card           43427  Yellow Cab
# 3             10000012        27703         Card           42375    Pink Cab
# 4             10320494        27703         Card           43211  Yellow Cab
# ...                ...          ...          ...             ...         ...
# 359387        10439790        38520         Card           43107  Yellow Cab
# 359388        10439799        12490         Cash           43103  Yellow Cab
# 359389        10439838        41414         Card           43104  Yellow Cab
# 359390        10439840        41677         Cash           43106  Yellow Cab
# 359391        10439846        39761         Card           43104  Yellow Cab
#
# ...

# %%
final_data = pd.merge(data1, city, how='inner', on='City')
final_data
# Out:
#         Transaction ID  Customer ID Payment_Mode  Date of Travel     Company  \
# 0             10000011        29290         Card           42377    Pink Cab
# 1             10351127        29290         Cash           43302  Yellow Cab
# 2             10412921        29290         Card           43427  Yellow Cab
# 3             10000012        27703         Card           42375    Pink Cab
# 4             10320494        27703         Card           43211  Yellow Cab
# ...                ...          ...          ...             ...         ...
# 359387        10307228        51406         Cash           43162  Yellow Cab
# 359388        10319775        51406         Cash           43203  Yellow Cab
# 359389        10347676        51406         Card           43287  Yellow Cab
# 359390        10358624        51406         Cash           43314  Yellow Cab
# 359391        10370709        51406         Card           43342  Yellow Cab
#
# ...

# %%
final_data.describe()
# Out:
#        Transaction ID    Customer ID  Date of Travel   KM Travelled  \
# count    3.593920e+05  359392.000000   359392.000000  359392.000000
# mean     1.022076e+07   19191.652115    42964.067998      22.567254
# std      1.268058e+05   21012.412463      307.467197      12.233526
# min      1.000001e+07       1.000000    42371.000000       1.900000
# 25%      1.011081e+07    2705.000000    42697.000000      12.000000
# 50%      1.022104e+07    7459.000000    42988.000000      22.440000
# 75%      1.033094e+07   36078.000000    43232.000000      32.960000
# max      1.044011e+07   60000.000000    43465.000000      48.000000
#
#        Price Charged   Cost of Trip            Age  Income (USD/Month)
# count  359392.000000  359392.000000  359392.000000       359392.000000
# mean      423.443311     286.190113      35.336705        15048.822937
# std       274.378911     157.993661      12.594234         7969.409482
# min        15.600000      19.000000      18.000000         2000.000000
# ...

# %% [markdown]
# # Data Analysis Steps
# #### 1.Missing values
# #### 2.Expore numerical variables
# #### 3.Profit for per km and per ride analysis
# #### 4.Yearly Profit Analysis
# #### 5.Income Class wise Profit and customer base Analysis
# #### 6.Age GroupWise Profit And Customer Base Analysis
# #### 7.Customer Retention
# #### 8.Customer Presence of Yellow and Pink cab city wise
# #### 9.User Covered by Company and Customer base Year wise
# #### 10.Customer analysis based on ride distance
# #### 11.Customer And Ride Analysis Day Wise
# #### 12. Profit Forecasting for 2019
# #### 13. Forecasting of no. of rides for 2019

# %% [markdown]
# ### 1. Missing values

# %%
final_data.isnull().sum()
# Out:
# Transaction ID        0
# Customer ID           0
# Payment_Mode          0
# Date of Travel        0
# Company               0
# City                  0
# KM Travelled          0
# Price Charged         0
# Cost of Trip          0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# Population            0
# Users                 0
# dtype: int64

# %% [markdown]
# ### 2. Explore numerical values

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359392 non-null  int64
#  1   Customer ID         359392 non-null  int64
#  2   Payment_Mode        359392 non-null  object
#  3   Date of Travel      359392 non-null  int64
#  4   Company             359392 non-null  object
#  5   City                359392 non-null  object
#  6   KM Travelled        359392 non-null  float64
#  7   Price Charged       359392 non-null  float64
#  8   Cost of Trip        359392 non-null  float64
#  9   Gender              359392 non-null  object
#  10  Age                 359392 non-null  int64
#  11  Income (USD/Month)  359392 non-null  int64
#  12  Population          359392 non-null  object
#  13  Users               359392 non-null  object
# dtypes: float64(3), int64(5), object(6)
# memory usage: 41.1+ MB

# %%
# Population and Users columns will change into numerical
final_data['Population'] = final_data.Population.str.replace(',','').astype(float)
final_data['Users'] = final_data.Users.str.replace(',','').astype(float)

# %%
print(final_data['Population'].dtype)
print(final_data['Users'].dtype)
# Out:
# float64
# float64

# %%
# converting date os travel to dates
min_date = final_data['Date of Travel'].agg('min')
max_date = final_data['Date of Travel'].agg('max')
print(min_date)
print(max_date)
max_date-min_date
# Out:
# 42371
# 43465
# 1094

# %%
current_date = pd.to_datetime('2016-01-31')
int(current_date.strftime("%Y%m%d"))
# Out:
# 20160131

# %%
base_date = datetime.date.fromordinal(datetime.datetime(2016,1,31).toordinal()-min_date)
base_date
# Out:
# datetime.date(1900, 1, 28)

# %%
final_data['Dates']= pd.to_datetime(final_data['Date of Travel'], unit='D', origin=pd.Timestamp('1900-01-28'))
final_data
# Out:
#         Transaction ID  Customer ID Payment_Mode  Date of Travel     Company  \
# 0             10000011        29290         Card           42377    Pink Cab
# 1             10351127        29290         Cash           43302  Yellow Cab
# 2             10412921        29290         Card           43427  Yellow Cab
# 3             10000012        27703         Card           42375    Pink Cab
# 4             10320494        27703         Card           43211  Yellow Cab
# ...                ...          ...          ...             ...         ...
# 359387        10307228        51406         Cash           43162  Yellow Cab
# 359388        10319775        51406         Cash           43203  Yellow Cab
# 359389        10347676        51406         Card           43287  Yellow Cab
# 359390        10358624        51406         Cash           43314  Yellow Cab
# 359391        10370709        51406         Card           43342  Yellow Cab
#
# ...

# %%
# Company profits
final_data['Profit'] = final_data['Price Charged'] - final_data['Cost of Trip']
final_data
# Out:
#         Transaction ID  Customer ID Payment_Mode  Date of Travel     Company  \
# 0             10000011        29290         Card           42377    Pink Cab
# 1             10351127        29290         Cash           43302  Yellow Cab
# 2             10412921        29290         Card           43427  Yellow Cab
# 3             10000012        27703         Card           42375    Pink Cab
# 4             10320494        27703         Card           43211  Yellow Cab
# ...                ...          ...          ...             ...         ...
# 359387        10307228        51406         Cash           43162  Yellow Cab
# 359388        10319775        51406         Cash           43203  Yellow Cab
# 359389        10347676        51406         Card           43287  Yellow Cab
# 359390        10358624        51406         Cash           43314  Yellow Cab
# 359391        10370709        51406         Card           43342  Yellow Cab
#
# ...

# %%
df = final_data.drop(['Date of Travel'], axis=1)
df.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode     Company        City  \
# 0        10000011        29290         Card    Pink Cab  ATLANTA GA
# 1        10351127        29290         Cash  Yellow Cab  ATLANTA GA
# 2        10412921        29290         Card  Yellow Cab  ATLANTA GA
# 3        10000012        27703         Card    Pink Cab  ATLANTA GA
# 4        10320494        27703         Card  Yellow Cab  ATLANTA GA
#
#    KM Travelled  Price Charged  Cost of Trip Gender  Age  Income (USD/Month)  \
# 0         30.45         370.95      313.6350   Male   28               10813
# 1         26.19         598.70      317.4228   Male   28               10813
# 2         42.55         792.05      597.4020   Male   28               10813
# 3         28.62         358.52      334.8540   Male   27                9237
# 4         36.38         721.10      467.1192   Male   27                9237
#
#    Population    Users      Dates    Profit
# 0    814885.0  24701.0 2016-02-06   57.3150
# ...

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Customer ID', 'Payment_Mode', 'Company', 'City',
#        'KM Travelled', 'Price Charged', 'Cost of Trip', 'Gender', 'Age',
#        'Income (USD/Month)', 'Population', 'Users', 'Dates', 'Profit'],
#       dtype='object')

# %% [markdown]
# ## 3.Profit for per km and per ride analysis

# %%
# According graph yellow cab making more money
sns.barplot(x='Company', y='Profit', data=df)
# Out:
# <AxesSubplot:xlabel='Company', ylabel='Profit'>

# %%
# Total profit for each company
total_profit = df.groupby('Company')['Profit'].sum()
print(total_profit)

#Total km driven by each company
total_km = df.groupby('Company')['KM Travelled'].sum()
print(total_km)

#Total number of rides for each company
number_of_rides = df['Company'].value_counts()
print(number_of_rides)
# Out:
# Company
# Pink Cab      5.307328e+06
# Yellow Cab    4.402037e+07
# Name: Profit, dtype: float64
# Company
# Pink Cab      1911073.11
# Yellow Cab    6199417.47
# Name: KM Travelled, dtype: float64
# Yellow Cab    274681
# Pink Cab       84711
# Name: Company, dtype: int64

# %%
# Yellow Cab making almost 2.5 time more money than Pink Cab for per ride
plt.figure(figsize=(10,8))
plt.bar(['Pink', 'Yellow'], total_profit, color = ['blue', 'orange'])

for index, value in enumerate(total_profit):
    plt.text(index, value+2,
             str(format(value, '.2f')))

plt.title('Total profit')
plt.savefig('total_profit.png')
plt.show()

# %%
#Profit that each company making from per ride
profit_per_ride = total_profit/number_of_rides
profit_per_ride
# Yellow Cab making almost 2.5 time more money than Pink Cab for per ride
plt.figure(figsize=(10,8))
plt.bar(['Pink', 'Yellow'], profit_per_ride, color = ['blue', 'orange'])

for index, value in enumerate(profit_per_ride):
    plt.text(index, value+2,
             str(format(value, '.2f')))

plt.title('Profit for per ride')
plt.savefig('per_ride.png')
plt.show()

# %%
# Profit that each company making from per km
profit_per_km = total_profit/total_km
print(profit_per_km)

# Yellow Cab making almost 2.5 time more money than Pink Cab for per km
plt.bar(['Pink', 'Yellow'], profit_per_km, color = ['blue', 'orange'])

for index, value in enumerate(profit_per_km):
    plt.text(index, value+0.1, str(format(value, '.2f')))
plt.title('Profit for per km')
plt.savefig('per_km.jpg')
plt.show()
# Out:
# Company
# Pink Cab      2.777146
# Yellow Cab    7.100727
# dtype: float64

# %%
df['Year'] = df['Dates'].dt.year
df
# Out:
#         Transaction ID  Customer ID Payment_Mode     Company           City  \
# 0             10000011        29290         Card    Pink Cab     ATLANTA GA
# 1             10351127        29290         Cash  Yellow Cab     ATLANTA GA
# 2             10412921        29290         Card  Yellow Cab     ATLANTA GA
# 3             10000012        27703         Card    Pink Cab     ATLANTA GA
# 4             10320494        27703         Card  Yellow Cab     ATLANTA GA
# ...                ...          ...          ...         ...            ...
# 359387        10307228        51406         Cash  Yellow Cab  WASHINGTON DC
# 359388        10319775        51406         Cash  Yellow Cab  WASHINGTON DC
# 359389        10347676        51406         Card  Yellow Cab  WASHINGTON DC
# 359390        10358624        51406         Cash  Yellow Cab  WASHINGTON DC
# 359391        10370709        51406         Card  Yellow Cab  WASHINGTON DC
#
# ...

# %% [markdown]
# ## 4.Yearly Profit Analysis

# %%
pink_2016_total = df[(df['Company'] == 'Pink Cab') & (df['Year'] == 2016)]['Profit'].sum()
pink_2017_total = df[(df['Company'] == 'Pink Cab') & (df['Year'] == 2017)]['Profit'].sum()
pink_2018_total = df[(df['Company'] == 'Pink Cab') & (df['Year'] == 2018)]['Profit'].sum()
yellow_2016_total = df[(df['Company'] == 'Yellow Cab') & (df['Year'] == 2016)]['Profit'].sum()
yellow_2017_total = df[(df['Company'] == 'Yellow Cab') & (df['Year'] == 2017)]['Profit'].sum()
yellow_2018_total = df[(df['Company'] == 'Yellow Cab') & (df['Year'] == 2018)]['Profit'].sum()
print(pink_2016_total)
print(pink_2017_total)
print(pink_2018_total)
print(yellow_2016_total)
print(yellow_2017_total)
print(yellow_2018_total)
# Out:
# 1388023.719
# 1977169.122
# 1680893.9980000001
# 12326843.6012
# 16337826.4324
# 13881733.042

# %%
# profit and loss in years for Pink Cab
profit_in_pink = ((pink_2017_total - pink_2016_total)/ pink_2016_total)*100
loss_in_pink = ((pink_2018_total - pink_2017_total)/ pink_2017_total)*100
print(profit_in_pink)
print(loss_in_pink)

# profit and loss in years for Yellow Cab
profit_in_yellow = ((yellow_2017_total - yellow_2016_total)/ yellow_2016_total)*100
loss_in_yellow = ((yellow_2018_total - yellow_2017_total)/ yellow_2017_total)*100
print(profit_in_yellow)
print(loss_in_yellow)
# Out:
# 42.44490889712238
# -14.984814435110314
# 32.538604049535735
# -15.033171031424676

# %%
pink_y = [pink_2016_total, pink_2017_total, pink_2018_total]
yellow_y = [yellow_2016_total, yellow_2017_total, yellow_2018_total]
x = [2016, 2017,2018]
plt.figure(figsize=(10,8))
plt.plot(x, pink_y, label = 'Pink Cab')
plt.plot(x, yellow_y, label = 'Yellow Cab')
plt.plot([2016, 2017, 2018], [1388023.719, 1977169.122,1680893.998], 'o')
plt.plot([2016, 2017, 2018], [12326843.6012, 16337826.43,13881733], 'o')
plt.text(2015.90, 1570000, '1388024')
plt.text(2016.92, 2300000, '1977169')
plt.text(2017.90, 1870000, '1680894')
plt.text(2015.90,13000000, '12326843')
plt.text(2016.92,16500000, '16337826')
plt.text(2017.88, 14500000, '13881733')

plt.annotate(f'Profit in % = {round(profit_in_pink, 2)}', xy=(2016.50, 2100000), xytext=(2016.25,3500000),
                   arrowprops=dict(facecolor='black', shrink = 0.01))

plt.annotate(f'Loss in % = {abs(round(loss_in_pink, 2))}', xy=(2017.50, 1900000), xytext=(2017.40,3800000),
                   arrowprops=dict(facecolor='black', shrink = 0.01))
plt.annotate(f'Profit in % = {round(profit_in_yellow, 2)}', xy=(2016.65, 14500000), xytext=(2016.45,11900000),
                   arrowprops=dict(facecolor='black', shrink = 0.01))
plt.annotate(f'Loss in % = {abs(round(loss_in_yellow, 2))}', xy=(2017.55, 14500000), xytext=(2017.40,13200000),
                   arrowprops=dict(facecolor='black', shrink = 0.01))
plt.title('Total profit by years for each company')
plt.xlabel('Years')
plt.ylabel('Profit')
plt.legend()
plt.savefig('yearly_profit.png')
plt.show()

# %%
# Average profit for per km in different years 
profit_by_year = df.groupby(['Company', 'Year'])['Profit'].mean()
km_driven  = df.groupby(['Company', 'Year'])['KM Travelled'].mean()
avg_profit_by_year = profit_by_year/km_driven
avg_profit_by_year
# Out:
# Company     Year
# Pink Cab    2016    2.845006
#             2017    2.941673
#             2018    2.498741
#             2019    3.333348
# Yellow Cab  2016    7.576508
#             2017    7.493664
#             2018    6.469714
#             2019    5.977944
# dtype: float64

# %% [markdown]
# ##  5. Income Class wise Profit and customer base Analysis

# %%
# Sum of the profit that made users  who have lower income than 2500 made for each company
df_pink_2016low_income = round(df[(df['Income (USD/Month)'] < 2500) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2016)]['Profit'].sum(), 1)
df_pink_2017low_income = round(df[(df['Income (USD/Month)'] < 2500) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2017)]['Profit'].sum(), 1)
df_pink_2018low_income = round(df[(df['Income (USD/Month)'] < 2500) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2018)]['Profit'].sum(), 1)

df_yellow_2016low_income = round(df[(df['Income (USD/Month)'] < 2500) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2016)]['Profit'].sum(), 1)
df_yellow_2017low_income = round(df[(df['Income (USD/Month)'] < 2500) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2017)]['Profit'].sum(), 1)
df_yellow_2018low_income = round(df[(df['Income (USD/Month)'] < 2500) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2018)]['Profit'].sum(), 1)

print(df_pink_2016low_income)
print(df_pink_2017low_income)
print(df_pink_2018low_income)
print(df_yellow_2016low_income)
print(df_yellow_2017low_income)
print(df_yellow_2018low_income)
# Out:
# 27094.8
# 35991.3
# 37458.8
# 227304.1
# 325910.3
# 258479.8

# %%
# Sum of the profit that made users  who have  income between $2500 and $15000 made for each company

df_pink_2016middle_income = round(df[(df['Income (USD/Month)'].between(2500, 15000)) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2016)]['Profit'].sum(), 1)
df_pink_2017middle_income = round(df[(df['Income (USD/Month)'].between(2500, 15000)) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2017)]['Profit'].sum(), 1)
df_pink_2018middle_income = round(df[(df['Income (USD/Month)'].between(2500, 15000)) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2018)]['Profit'].sum(), 1)

df_yellow_2016middle_income = round(df[(df['Income (USD/Month)'].between(2500, 15000)) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2016)]['Profit'].sum(), 1)
df_yellow_2017middle_income = round(df[(df['Income (USD/Month)'].between(2500, 15000)) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2017)]['Profit'].sum(), 1)
df_yellow_2018middle_income = round(df[(df['Income (USD/Month)'].between(2500, 15000)) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2018)]['Profit'].sum(), 1)

print(df_pink_2016middle_income)
print(df_pink_2017middle_income)
print(df_pink_2018middle_income)
print(df_yellow_2016middle_income)
print(df_yellow_2017middle_income)
print(df_yellow_2018middle_income)
# Out:
# 659566.6
# 973477.7
# 817712.4
# 6008154.2
# 7921654.7
# 6785298.1

# %%
# Sum of the profit that made users  who have  income higher than $15000 made for each company

df_pink_2016high_income = round(df[(df['Income (USD/Month)'] > 15000) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2016)]['Profit'].sum(), 1)
df_pink_2017high_income = round(df[(df['Income (USD/Month)'] > 15000) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2017)]['Profit'].sum(), 1)
df_pink_2018high_income = round(df[(df['Income (USD/Month)'] > 15000) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2018)]['Profit'].sum(), 1)

df_yellow_2016high_income = round(df[(df['Income (USD/Month)'] > 15000) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2016)]['Profit'].sum(), 1)
df_yellow_2017high_income = round(df[(df['Income (USD/Month)'] >  15000) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2017)]['Profit'].sum(), 1)
df_yellow_2018high_income = round(df[(df['Income (USD/Month)'] > 15000) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2018)]['Profit'].sum(), 1)

print(df_pink_2016high_income)
print(df_pink_2017high_income)
print(df_pink_2018high_income)
print(df_yellow_2016high_income)
print(df_yellow_2017high_income)
print(df_yellow_2018high_income)
# Out:
# 701362.4
# 967700.1
# 825722.8
# 6091385.3
# 8090261.5
# 6837955.2

# %%
class_y1 = [df_pink_2016low_income, df_yellow_2016low_income ,df_pink_2017low_income, df_yellow_2017low_income, df_pink_2018low_income, df_yellow_2018low_income]
class_y2 = [df_pink_2016middle_income, df_yellow_2016middle_income, df_pink_2017middle_income, df_yellow_2017middle_income, df_pink_2018middle_income, df_yellow_2018middle_income]
class_y3 = [df_pink_2016high_income, df_yellow_2016high_income, df_pink_2017high_income, df_yellow_2017high_income, df_pink_2018high_income, df_yellow_2018high_income]

class_df = pd.DataFrame({
    '<2500':class_y1,
    '2500-15000':class_y2,
    '>15000':class_y3
})

labels = ['Pink Cab', 'Yellow Cab', 'Pink Cab', 'Yellow Cab', 'Pink Cab', 'Yellow Cab']

ax = class_df.plot(stacked=True, kind='bar', width = 0.6, figsize=(10,8))
for bar in ax.patches:
    height = bar.get_height()
    width = bar.get_width()
    x = bar.get_x()
    y = bar.get_y()
    label_text = height
    label__x = x + width/2
    label_y = y+height/2
    ax.text(label__x, label_y, label_text, ha = 'center', va = 'center')

ax.set_xticklabels(labels, rotation = 'horizontal')
ax.set_title('Inccome class-wise profit analyses')
plt.legend(title = 'Income USD month')
plt.savefig('class-wise_profit.png')
plt.show()

# %% [markdown]
# ## 6. Age GroupWise Profit And Customer Base Analysis

# %%
# Sum of the profit that users  who have age between 18 and 25 for each company
all_years = ['2016', '2017', '2018']
pink_18_25_profit = []
yellow_18_25_profit = []
pink_26_40_profit = []
yellow_26_40_profit = []
pink_41_60_profit = []
yellow_41_60_profit = []
pink_60_profit = []
yellow_60_profit = []
for i in range(len(all_years)):
   pink_18_25_profit.append(round(df[(df['Age'].between(18,25)) & (df['Company'] == 'Pink Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Profit'].sum(), 0))
   yellow_18_25_profit.append(round(df[(df['Age'].between(18,25)) & (df['Company'] == 'Yellow Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Profit'].sum(), 0))
   pink_26_40_profit.append(round(df[(df['Age'].between(26,40)) & (df['Company'] == 'Pink Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Profit'].sum(), 0))
   yellow_26_40_profit.append(round(df[(df['Age'].between(26,40)) & (df['Company'] == 'Yellow Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Profit'].sum(), 0))
   pink_41_60_profit.append(round(df[(df['Age'].between(41,60)) & (df['Company'] == 'Pink Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Profit'].sum(), 0))
   yellow_41_60_profit.append(round(df[(df['Age'].between(41,60)) & (df['Company'] == 'Yellow Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Profit'].sum(), 0))
   pink_60_profit.append(round(df[(df['Age'] > 60) & (df['Company'] == 'Pink Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Profit'].sum(), 0))
   yellow_60_profit.append(round(df[(df['Age'] > 60) & (df['Company'] == 'Yellow Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Profit'].sum(), 0))
print(pink_18_25_profit)
print(yellow_18_25_profit)
print(pink_26_40_profit)
print(yellow_26_40_profit)
print(pink_60_profit)
print(yellow_60_profit)
# Out:
# [359973.0, 526966.0, 448285.0]
# [3195790.0, 4246063.0, 3625720.0]
# [650263.0, 929947.0, 794687.0]
# [5857410.0, 7697205.0, 6525097.0]
# [79649.0, 99640.0, 88364.0]
# [599577.0, 831480.0, 689848.0]

# %%
#Analyse profitshare by agegroup

p_y1 = [pink_60_profit[0],  yellow_60_profit[0], pink_60_profit[1], yellow_60_profit[1], pink_60_profit[2], yellow_60_profit[2]]
p_y2 = [pink_41_60_profit[0], yellow_41_60_profit[0], pink_41_60_profit[1], yellow_41_60_profit[1], pink_41_60_profit[2], yellow_41_60_profit[2]]
p_y3 = [pink_26_40_profit[0], yellow_26_40_profit[0], pink_26_40_profit[1], yellow_26_40_profit[1], pink_26_40_profit[2], yellow_26_40_profit[2]]
p_y4 = [pink_18_25_profit[0], yellow_18_25_profit[0], pink_18_25_profit[1], yellow_18_25_profit[1], pink_18_25_profit[2], yellow_18_25_profit[2]]

profit_df = pd.DataFrame({
    '60+':p_y1,
    '41-60':p_y2,
    '26-40':p_y3,
    '18-25':p_y4
})


labels = ['Pink Cab', 'Yellow Cab', 'Pink Cab', 'Yellow Cab', 'Pink Cab', 'Yellow Cab']

ax = profit_df.plot(stacked=True, kind='bar', width = 0.6, figsize=(10,8))
for bar in ax.patches:
    height = bar.get_height()
    width = bar.get_width()
    x = bar.get_x()
    y = bar.get_y()
    label_text = height
    label__x = x + width/2
    label_y = y+height/2
    ax.text(label__x, label_y, label_text, ha = 'center', va = 'center')

ax.set_xticklabels(labels, rotation = 'horizontal')
ax.set_title('Profitshare by Agegroup')
plt.legend(title = 'Age(group)')
plt.savefig('profit_byage.png')
plt.show()

# %%
# Total number of customers of each company in different ages by given years

all_years = ['2016', '2017', '2018']
pink_18_25_customers = []
yellow_18_25_customers = []
pink_26_40_customers = []
yellow_26_40_customers = []
pink_41_60_customers = []
yellow_41_60_customers = []
pink_60_customers = []
yellow_60_customers = []
for i in range(len(all_years)):
   pink_18_25_customers.append(df[(df['Age'].between(18,25)) & (df['Company'] == 'Pink Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Customer ID'].unique().sum())
   yellow_18_25_customers.append(df[(df['Age'].between(18,25)) & (df['Company'] == 'Yellow Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Customer ID'].unique().sum())
   pink_26_40_customers.append(df[(df['Age'].between(26,40)) & (df['Company'] == 'Pink Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Customer ID'].unique().sum())
   yellow_26_40_customers.append(df[(df['Age'].between(26,40)) & (df['Company'] == 'Yellow Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Customer ID'].unique().sum())
   pink_41_60_customers.append(df[(df['Age'].between(41,60)) & (df['Company'] == 'Pink Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Customer ID'].unique().sum())
   yellow_41_60_customers.append(df[(df['Age'].between(41,60)) & (df['Company'] == 'Yellow Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Customer ID'].unique().sum())
   pink_60_customers.append(df[(df['Age'] > 60) & (df['Company'] == 'Pink Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Customer ID'].unique().sum())
   yellow_60_customers.append(df[(df['Age'] > 60) & (df['Company'] == 'Yellow Cab') & (df['Year'] == int(f'{all_years[i]}'))]['Customer ID'].unique().sum())
print(pink_18_25_customers)
print(yellow_18_25_customers)
print(pink_26_40_customers)
print(yellow_26_40_customers)
print(pink_60_customers)
print(yellow_60_customers)
# Out:
# [83560547, 108194649, 103957400]
# [157690949, 179692979, 180284449]
# [156376952, 196278346, 198540701]
# [295476807, 334983413, 337412556]
# [16950663, 22572419, 21941755]
# [32022805, 37338799, 35411003]

# %%
# Total number of customers based on years
all_years = ['2016', '2017', '2018']
all_customers_by_year = []
for i in range(len(all_years)):
   all_customers_by_year.append(df[(df['Year'] == int(f'{all_years[i]}'))]['Customer ID'].unique().sum())

all_customers_by_year
# Out:
# [758222508, 864998466, 862525756]

# %%
# % of customers of each company in different ages by given years

pink_18_25_rel = []
yellow_18_25_rel = []
pink_26_40_rel = []
yellow_26_40_rel = []
pink_41_60_rel = []
yellow_41_60_rel = []
pink_60_rel = []
yellow_60_rel = []
for i in range(len(all_customers_by_year)):
    pink_18_25_rel.append(round((pink_18_25_customers[i]/all_customers_by_year[i])*100, 2))
    yellow_18_25_rel.append(round((yellow_18_25_customers[i]/all_customers_by_year[i])*100, 2))
    pink_26_40_rel.append(round((pink_26_40_customers[i]/all_customers_by_year[i])*100, 2))
    yellow_26_40_rel.append(round((yellow_26_40_customers[i]/all_customers_by_year[i])*100, 2))
    pink_41_60_rel.append(round((pink_41_60_customers[i]/all_customers_by_year[i])*100, 2))
    yellow_41_60_rel.append(round((yellow_41_60_customers[i]/all_customers_by_year[i])*100, 3))
    pink_60_rel.append(round((pink_60_customers[i]/all_customers_by_year[i])*100, 2))
    yellow_60_rel.append(round((yellow_60_customers[i]/all_customers_by_year[i])*100, 2))
    
print(pink_18_25_rel)
print(yellow_18_25_rel)    
print(pink_26_40_rel)    
print(yellow_26_40_rel)    
print(pink_41_60_rel)    
print(yellow_41_60_rel)    
print(pink_60_rel)    
print(yellow_60_rel)
# Out:
# [11.02, 12.51, 12.05]
# [20.8, 20.77, 20.9]
# [20.62, 22.69, 23.02]
# [38.97, 38.73, 39.12]
# [8.97, 9.91, 9.91]
# [17.122, 17.088, 16.841]
# [2.24, 2.61, 2.54]
# [4.22, 4.32, 4.11]

# %%
#Analyse of customer segmentation by agegroup

p_y1 = [pink_60_rel[0],  yellow_60_rel[0], pink_60_rel[1], yellow_60_rel[1], pink_60_rel[2], yellow_60_rel[2]]
p_y2 = [pink_41_60_rel[0], yellow_41_60_rel[0], pink_41_60_rel[1], yellow_41_60_rel[1], pink_41_60_rel[2], yellow_41_60_rel[2]]
p_y3 = [pink_26_40_rel[0], yellow_26_40_rel[0], pink_26_40_rel[1], yellow_26_40_rel[1], pink_26_40_rel[2], yellow_26_40_rel[2]]
p_y4 = [pink_18_25_rel[0], yellow_18_25_rel[0], pink_18_25_rel[1], yellow_18_25_rel[1], pink_18_25_rel[2], yellow_18_25_rel[2]]


# yel_y1 = [yellow_60_rel[0], yellow_60_rel[1], yellow_60_rel[2]]
# yel_y2 = [yellow_41_60_rel[0], yellow_41_60_rel[1], yellow_41_60_rel[2]]
# yel_y3 = [yellow_26_40_rel[0], yellow_26_40_rel[1], yellow_26_40_rel[2]]
# yel_y4 = [yellow_18_25_rel[0], yellow_18_25_rel[1], yellow_18_25_rel[2]]

seg_df = pd.DataFrame({
    '60+':p_y1,
    '41-60':p_y2,
    '26-40':p_y3,
    '18-25':p_y4
})


labels = ['Pink Cab', 'Yellow Cab', 'Pink Cab', 'Yellow Cab', 'Pink Cab', 'Yellow Cab']

ax = seg_df.plot(stacked=True, kind='bar', figsize=(10,8))

for bar in ax.patches:
    height = bar.get_height()
    width = bar.get_width()
    x = bar.get_x()
    y = bar.get_y()
    label_text = height
    label__x = x + width/2
    label_y = y+height/2
    ax.text(label__x, label_y, label_text, ha = 'center', va = 'center')

ax.set_xticklabels(labels, rotation = 'horizontal')
ax.set_title('Customer segmentation by Agegroup')
plt.legend(title = 'Age(group)')
plt.savefig('seg_byage.png')
plt.show()

# %% [markdown]
# ## 7. Customer Retention

# %%
# Customers who have taken at least 5 rides of the Pink cab company in different years

pink_2016 = df[(df['Customer ID'].value_counts() > 5) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2016)]
pink_2017 = df[(df['Customer ID'].value_counts() > 5) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2017)]
pink_2018 = df[(df['Customer ID'].value_counts() > 5) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2018)]
pink_2016_min_5rides = pink_2016['Customer ID'].value_counts().sum()
pink_2017_min_5rides = pink_2017['Customer ID'].value_counts().sum()
pink_2018_min_5rides = pink_2018['Customer ID'].value_counts().sum()

print(pink_2016_min_5rides)
print(pink_2017_min_5rides)
print(pink_2018_min_5rides)
# Out:
# 1139
# 1228
# 1240

# %%
# Customers who have taken at least 5 rides of the Yellow cab company in different years

yellow_2016 = df[(df['Customer ID'].value_counts() > 5) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2016)]
yellow_2017 = df[(df['Customer ID'].value_counts() > 5) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2017)]
yellow_2018 = df[(df['Customer ID'].value_counts() > 5) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2018)]
yellow_2016_min_5rides = yellow_2016['Customer ID'].value_counts().sum()
yellow_2017_min_5rides = yellow_2017['Customer ID'].value_counts().sum()
yellow_2018_min_5rides = yellow_2018['Customer ID'].value_counts().sum()

print(yellow_2016_min_5rides)
print(yellow_2017_min_5rides)
print(yellow_2018_min_5rides)
# Out:
# 4078
# 4674
# 4524

# %%
# Analyses customers who have taken at least 5 rides
all_pink_5rides = [pink_2016_min_5rides, pink_2017_min_5rides, pink_2018_min_5rides]
all_yellow_5rides = [yellow_2016_min_5rides, yellow_2017_min_5rides, yellow_2018_min_5rides]
import circlify

# compute circle positions:
circles1 = circlify.circlify(
    all_pink_5rides, 
    show_enclosure=False, 
    target_enclosure=circlify.Circle(x=10, y=-10, r=8)
)
circles2 =circlify.circlify(
    all_yellow_5rides,
    show_enclosure = False,
    target_enclosure = circlify.Circle(x=10, y=10, r=20)
)
fig, ax = plt.subplots(figsize=(10,10))

# Title
ax.set_title('Customer retention(at least 5 rides)')

# Remove axes
ax.axis('off')

# Find axis boundaries
lim1 = max(
    max(
        abs(circle1.x) + circle1.r,
        abs(circle1.y) + circle1.r,
    )
    for circle1 in circles1
)
plt.xlim(-lim1, lim1)
plt.ylim(-lim1, lim1)

lim2 = max(
    max(
        abs(circle2.x) + circle2.r,
        abs(circle2.y) + circle2.r,
    )
    for circle2 in circles2
)
plt.xlim(-lim2, lim2)
plt.ylim(-lim2, lim2)

# list of labels
labels1 = ['Pink Cab\n2016\n1139', 'Pink Cab\n2017\n1228', 'Pink Cab\n2018\n1240']
labels2 = ['Yellow Cab\n2016\n4078', 'Yellow Cab\n2017\n4674', 'Yellow Cab\n2018\n4524']
# print circles
for circle1, label in zip(circles1, labels1):
    x, y, r = circle1
    ax.add_patch(plt.Circle((x, y), r, alpha=1, linewidth=1, facecolor = 'blue'))
    plt.annotate(
          label, 
          (x,y ) ,
          va='center',
          ha='center'
     )
for circle2, label in zip(circles2, labels2):
    x, y, r = circle2
    ax.add_patch(plt.Circle((x, y), r, alpha=1, linewidth=2, facecolor = 'orange'))
    plt.annotate(
          label, 
          (x,y ) ,
          va='center',
          ha='center'
     ) 

plt.savefig('customer_5rides.png')
plt.show()

# %%
# Customers who have taken at least 10 rides of the Pink cab company in different years

pink_2016 = df[(df['Customer ID'].value_counts() > 10) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2016)]
pink_2017 = df[(df['Customer ID'].value_counts() > 10) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2017)]
pink_2018 = df[(df['Customer ID'].value_counts() > 10) & (df['Company'] == 'Pink Cab') & (df['Year'] == 2018)]
pink_2016_min_10rides = pink_2016['Customer ID'].value_counts().sum()
pink_2017_min_10rides = pink_2017['Customer ID'].value_counts().sum()
pink_2018_min_10rides = pink_2018['Customer ID'].value_counts().sum()

print(pink_2016_min_10rides)
print(pink_2017_min_10rides)
print(pink_2018_min_10rides)
# Out:
# 910
# 965
# 943

# %%
# Customers who have taken at least 10 rides of the Yellow cab company in different years

yellow_2016 = df[(df['Customer ID'].value_counts() > 10) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2016)]
yellow_2017 = df[(df['Customer ID'].value_counts() > 10) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2017)]
yellow_2018 = df[(df['Customer ID'].value_counts() > 10) & (df['Company'] == 'Yellow Cab') & (df['Year'] == 2018)]
yellow_2016_min_10rides = yellow_2016['Customer ID'].value_counts().sum()
yellow_2017_min_10rides = yellow_2017['Customer ID'].value_counts().sum()
yellow_2018_min_10rides = yellow_2018['Customer ID'].value_counts().sum()

print(yellow_2016_min_10rides)
print(yellow_2017_min_10rides)
print(yellow_2018_min_10rides)
# Out:
# 2915
# 3349
# 3229

# %%
# Analyses customers who have taken at least 5 rides
all_pink_10rides = [pink_2016_min_10rides, pink_2017_min_10rides, pink_2018_min_10rides]
all_yellow_10rides = [yellow_2016_min_10rides, yellow_2017_min_10rides, yellow_2018_min_10rides]
import circlify

# compute circle positions:
circles1 = circlify.circlify(
    all_pink_10rides, 
    show_enclosure=False, 
    target_enclosure=circlify.Circle(x=10, y=-10, r=8)
)
circles2 =circlify.circlify(
    all_yellow_10rides,
    show_enclosure = False,
    target_enclosure = circlify.Circle(x=10, y=10, r=20)
)
fig, ax = plt.subplots(figsize=(10,10))

# Title
ax.set_title('Customer retention(at least 10 rides)')

# Remove axes
ax.axis('off')

# Find axis boundaries
lim1 = max(
    max(
        abs(circle1.x) + circle1.r,
        abs(circle1.y) + circle1.r,
    )
    for circle1 in circles1
)
plt.xlim(-lim1, lim1)
plt.ylim(-lim1, lim1)

lim2 = max(
    max(
        abs(circle2.x) + circle2.r,
        abs(circle2.y) + circle2.r,
    )
    for circle2 in circles2
)
plt.xlim(-lim2, lim2)
plt.ylim(-lim2, lim2)

# list of labels
labels1 = ['Pink Cab\n2016\n910', 'Pink Cab\n2017\n965', 'Pink Cab\n2018\n943']
labels2 = ['Yellow Cab\n2016\n2915', 'Yellow Cab\n2017\n3349', 'Yellow Cab\n2018\n3229']
# print circles
for circle1, label in zip(circles1, labels1):
    x, y, r = circle1
    ax.add_patch(plt.Circle((x, y), r, alpha=1, linewidth=1, facecolor = 'blue'))
    plt.annotate(
          label, 
          (x,y ) ,
          va='center',
          ha='center'
     )
for circle2, label in zip(circles2, labels2):
    x, y, r = circle2
    ax.add_patch(plt.Circle((x, y), r, alpha=1, linewidth=2, facecolor = 'orange'))
    plt.annotate(
          label, 
          (x,y ) ,
          va='center',
          ha='center'
     )
plt.savefig('customer_10rides.png')
plt.show()

# %% [markdown]
# ## 8. Customer Presence of Yellow and Pink cab city wise

# %%
# Number of users in different cities for Pink Cab Company
cities = df['City'].unique().tolist()
pink_users_by_city = []
for i in range(len(cities)):
    pink_users_by_city.append(len(df[(df['City'] == f'{cities[i]}') & (df['Company'] == 'Pink Cab')]['Customer ID'].unique()))

pink_users_by_city
# Out:
# [1322,
#  1354,
#  2463,
#  2859,
#  1118,
#  1145,
#  2996,
#  1480,
#  1356,
#  2972,
#  1198,
#  763,
#  604,
#  1078,
#  2909,
#  1790,
#  2130,
#  684,
#  2109]

# %%
# Number of users in different cities for Yellow Cab Company

cities = df['City'].unique().tolist()
yellow_users_by_city = []
for i in range(len(cities)):
    yellow_users_by_city.append(len(df[(df['City'] == f'{cities[i]}') & (df['Company'] == 'Yellow Cab')]['Customer ID'].unique()))

yellow_users_by_city
# Out:
# [2595,
#  1914,
#  2997,
#  3000,
#  2564,
#  1681,
#  2998,
#  2334,
#  965,
#  3000,
#  1712,
#  994,
#  574,
#  880,
#  2886,
#  2486,
#  2382,
#  934,
#  3000]

# %%
df2 = pd.DataFrame({'cities':cities, 'pink_users_by_city':pink_users_by_city, 'yellow_users_by_city':yellow_users_by_city})
df2
# Out:
#             cities  pink_users_by_city  yellow_users_by_city
# 0       ATLANTA GA                1322                  2595
# 1        AUSTIN TX                1354                  1914
# 2        BOSTON MA                2463                  2997
# 3       CHICAGO IL                2859                  3000
# 4        DALLAS TX                1118                  2564
# 5        DENVER CO                1145                  1681
# 6   LOS ANGELES CA                2996                  2998
# 7         MIAMI FL                1480                  2334
# 8     NASHVILLE TN                1356                   965
# 9      NEW YORK NY                2972                  3000
# 10   ORANGE COUNTY                1198                  1712
# 11      PHOENIX AZ                 763                   994
# 12   PITTSBURGH PA                 604                   574
# 13   SACRAMENTO CA                1078                   880
# ...

# %%
ind = cities
 
# plot the bars
fig, ax = plt.subplots(figsize =(12, 8))
ax.barh(ind, yellow_users_by_city, left = pink_users_by_city, color = 'orange', label = 'Yellow Cab')
ax.barh(ind, pink_users_by_city, color = 'b', label = 'Pink Cab')

for i in ax.patches:
    ax.text(i.get_width()-300, i.get_y()+0.3,
             str(round((i.get_width()), 2)),
             fontsize = 10)
ax.set_title("Customers presence citywise")
plt.legend(loc = 'upper left', bbox_to_anchor=(0.85,1), ncol=1, title = 'Company')
plt.savefig('presence_citywise.png')
plt.show()

# %% [markdown]
# ## 9. User Covered by Company and Customer base Year wise

# %%
# total numbers of users

total_users = df['Users'].sum()
print(total_users)

# percentage of users that covered by Pink Cab company

covered_by_pink = (df[(df['Profit'] < 0) & (df['Company'] == 'Pink Cab')])['Users'].sum()
percentage_cov_by_pink = (covered_by_pink/total_users)*100
print(percentage_cov_by_pink)

# percentage of users that covered by Yellow Cab company

covered_by_yellow = (df[(df['Profit'] < 0) & (df['Company'] == 'Yellow Cab')])['Users'].sum()
percentage_cov_by_yellow = (covered_by_yellow/total_users)*100
print(percentage_cov_by_yellow)


# Yellow cab has reach of around
# 2.4% cab users while Pink cab
# has 1.897% reach.
# Out:
# 56915323342.0
# 1.8974987658605649
# 2.9260805442372777

# %%
# Graph shows percentage of users covered by company

df1 = pd.DataFrame({'Companies':['Pink Cab', 'Yellow Cab'], 'Percentages':[ percentage_cov_by_pink, percentage_cov_by_yellow]})

plt.figure(figsize=(8, 6))
 

plots = sns.barplot(x="Companies", y="Percentages", data=df1)
 
# Iterrating over the bars one-by-one
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
 
plt.xlabel("Companies", size=14)
plt.ylabel("%' of users covered", size=14)
plt.title("Users Covered by Company")
plt.savefig('users_cov.png')
plt.show()

# %%
# Number of Customers by years for Pink Cab company

pink_2016_customers =  len((df[(df['Company'] == 'Pink Cab') & (df['Year'] == 2016)])['Customer ID'].unique())
pink_2017_customers =  len((df[(df['Company'] == 'Pink Cab') & (df['Year'] == 2017)])['Customer ID'].unique())
pink_2018_customers =  len((df[(df['Company'] == 'Pink Cab') & (df['Year'] == 2018)])['Customer ID'].unique())
print(pink_2016_customers)

# Number of Customers by years for Yellow Cab company

yellow_2016_customers =  len((df[(df['Company'] == 'Yellow Cab') & (df['Year'] == 2016)])['Customer ID'].unique())
yellow_2017_customers =  len((df[(df['Company'] == 'Yellow Cab') & (df['Year'] == 2017)])['Customer ID'].unique())
yellow_2018_customers =  len((df[(df['Company'] == 'Yellow Cab') & (df['Year'] == 2018)])['Customer ID'].unique())
print(yellow_2016_customers)
# Out:
# 15107
# 24455

# %%
# Number of cutomers by years for each company

pink_byyear_customers = [pink_2016_customers, pink_2017_customers, pink_2018_customers]
yellow_byyear_customers = [yellow_2016_customers, yellow_2017_customers, yellow_2018_customers]

years = [2016, 2017, 2018]
ind = np.arange(len(pink_byyear_customers))

fig, ax = plt.subplots(figsize = (10,8))
ax.bar(ind, yellow_byyear_customers, color='orange', edgecolor='white', width=0.85, label = 'Yellow Cab')
ax.bar(ind, pink_byyear_customers, bottom=yellow_byyear_customers, color='blue', edgecolor='white', width=0.85, label = 'Pink Cab')
ax.set_xticks(ind, years)
ax.set_xlabel("Years", size = 14)
ax.set_ylabel("No of customers")
ax.set_title('Customer count vs Year', size = 14)
for i, v in enumerate(yellow_byyear_customers):
    ax.text(i-.15,  
              v-8000, 
              yellow_byyear_customers[i], 
              fontsize=12)

for j, k in enumerate(pink_byyear_customers): 
    ax.text(j-.15,  
                2*k, 
                pink_byyear_customers[j], 
                fontsize=12)
plt.legend(loc = 'upper left', bbox_to_anchor=(0,1), ncol=1, title = 'Company')
plt.savefig('Customervsyear.png')
plt.show()

# %% [markdown]
# ## 10. Customer analysis based on ride distance

# %%
# Number of Customers based on distance of ride for Pink Cab company

pink_0km =  len((df[(df['Company'] == 'Pink Cab') & (df['KM Travelled'] < 5 )])['Customer ID'].unique())
pink_5km =  len((df[(df['Company'] == 'Pink Cab') & (df['KM Travelled'].between(5,10))])['Customer ID'].unique())
pink_10km =  len((df[(df['Company'] == 'Pink Cab') & (df['KM Travelled'].between(10,15))])['Customer ID'].unique())
pink_15km =  len((df[(df['Company'] == 'Pink Cab') & (df['KM Travelled'].between(15,20))])['Customer ID'].unique())
pink_20km =  len((df[(df['Company'] == 'Pink Cab') & (df['KM Travelled'].between(20,25))])['Customer ID'].unique())
pink_25km =  len((df[(df['Company'] == 'Pink Cab') & (df['KM Travelled'].between(25,30))])['Customer ID'].unique())
pink_30km =  len((df[(df['Company'] == 'Pink Cab') & (df['KM Travelled'].between(30,35))])['Customer ID'].unique())
pink_35km =  len((df[(df['Company'] == 'Pink Cab') & (df['KM Travelled'].between(35,40))])['Customer ID'].unique())
pink_40km =  len((df[(df['Company'] == 'Pink Cab') & (df['KM Travelled'].between(40,45))])['Customer ID'].unique())
pink_45km =  len((df[(df['Company'] == 'Pink Cab') & (df['KM Travelled'] > 45 )])['Customer ID'].unique())
print(pink_0km)
print(pink_20km)
print(pink_35km)
print(pink_45km)
# Out:
# 6048
# 8456
# 8171
# 1234

# %%
# Number of Customers based on distance of ride for Yellow Cab company

yellow_0km =  len((df[(df['Company'] == 'Yellow Cab') & (df['KM Travelled'] < 5 )])['Customer ID'].unique())
yellow_5km =  len((df[(df['Company'] == 'Yellow Cab') & (df['KM Travelled'].between(5,10))])['Customer ID'].unique())
yellow_10km =  len((df[(df['Company'] == 'Yellow Cab') & (df['KM Travelled'].between(10,15))])['Customer ID'].unique())
yellow_15km =  len((df[(df['Company'] == 'Yellow Cab') & (df['KM Travelled'].between(15,20))])['Customer ID'].unique())
yellow_20km =  len((df[(df['Company'] == 'Yellow Cab') & (df['KM Travelled'].between(20,25))])['Customer ID'].unique())
yellow_25km =  len((df[(df['Company'] == 'Yellow Cab') & (df['KM Travelled'].between(25,30))])['Customer ID'].unique())
yellow_30km =  len((df[(df['Company'] == 'Yellow Cab') & (df['KM Travelled'].between(30,35))])['Customer ID'].unique())
yellow_35km =  len((df[(df['Company'] == 'Yellow Cab') & (df['KM Travelled'].between(35,40))])['Customer ID'].unique())
yellow_40km =  len((df[(df['Company'] == 'Yellow Cab') & (df['KM Travelled'].between(40,45))])['Customer ID'].unique())
yellow_45km =  len((df[(df['Company'] == 'Yellow Cab') & (df['KM Travelled'] > 45 )])['Customer ID'].unique())
print(yellow_0km)
print(yellow_20km)
print(yellow_35km)
print(yellow_45km)
# Out:
# 13693
# 17184
# 16822
# 3736

# %%
#Customer analyses based on ride distance

pink_km_customers = [pink_0km, pink_5km, pink_10km, pink_15km, pink_20km, pink_25km, pink_30km, pink_35km, pink_40km, pink_45km]
yellow_km_customers = [yellow_0km, yellow_5km, yellow_10km, yellow_15km, yellow_20km, yellow_25km, yellow_30km, yellow_35km, yellow_40km, yellow_45km]

kms = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]

fig, ax = plt.subplots()    
ind = np.arange(len(pink_km_customers))  
ax.bar(ind, yellow_km_customers, color='orange', edgecolor='white', width=0.85, label = 'Yellow Cab')
ax.bar(ind, pink_km_customers, bottom=yellow_km_customers, color='blue', edgecolor='white', width=0.85, label = 'Pink Cab')
ax.set_xticks(ind, kms)
ax.set_xlabel("Distance(km)")
ax.set_ylabel("No of customers")
ax.set_title('Customers vs KM Travelled')
for i, v in enumerate(yellow_km_customers):
    ax.text(i-.35,  
              v-3000, 
              yellow_km_customers[i], 
              fontsize=8)

for j, k in enumerate(pink_km_customers): 
    ax.text(j-.35,  
                2.8*k, 
                pink_km_customers[j], 
                fontsize=8)
plt.legend(loc = 'upper left', bbox_to_anchor=(0.8,1), ncol=1, title = 'Company')
plt.savefig('cus_vs_km.png')
plt.show()

# %% [markdown]
# ## 11. Customer And Ride Analysis Day Wise

# %%
df['Days'] = df['Dates'].dt.day_name()
df
# Out:
#         Transaction ID  Customer ID Payment_Mode     Company           City  \
# 0             10000011        29290         Card    Pink Cab     ATLANTA GA
# 1             10351127        29290         Cash  Yellow Cab     ATLANTA GA
# 2             10412921        29290         Card  Yellow Cab     ATLANTA GA
# 3             10000012        27703         Card    Pink Cab     ATLANTA GA
# 4             10320494        27703         Card  Yellow Cab     ATLANTA GA
# ...                ...          ...          ...         ...            ...
# 359387        10307228        51406         Cash  Yellow Cab  WASHINGTON DC
# 359388        10319775        51406         Cash  Yellow Cab  WASHINGTON DC
# 359389        10347676        51406         Card  Yellow Cab  WASHINGTON DC
# 359390        10358624        51406         Cash  Yellow Cab  WASHINGTON DC
# 359391        10370709        51406         Card  Yellow Cab  WASHINGTON DC
#
# ...

# %%
# Number of customers based on days of the week  for Pink Cab company

pink_mon_customers =  len((df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Monday' )])['Customer ID'].unique())
pink_tues_customers =  len((df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Tuesday' )])['Customer ID'].unique())
pink_wedn_customers =  len((df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Wednesday' )])['Customer ID'].unique())
pink_thurs_customers =  len((df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Thursday' )])['Customer ID'].unique())
pink_fri_customers =  len((df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Friday' )])['Customer ID'].unique())
pink_satur_customers =  len((df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Saturday' )])['Customer ID'].unique())
pink_sunday_customers =  len((df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Sunday' )])['Customer ID'].unique())

print(pink_mon_customers)
print(pink_wedn_customers)
print(pink_satur_customers)
print(pink_sunday_customers)
# Out:
# 12334
# 6167
# 13755
# 13248

# %%
# Number of customers based on days of the week  for Yellow Cab company

yellow_mon_customers =  len((df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Monday' )])['Customer ID'].unique())
yellow_tues_customers =  len((df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Tuesday' )])['Customer ID'].unique())
yellow_wedn_customers =  len((df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Wednesday' )])['Customer ID'].unique())
yellow_thurs_customers =  len((df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Thursday' )])['Customer ID'].unique())
yellow_fri_customers =  len((df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Friday' )])['Customer ID'].unique())
yellow_satur_customers =  len((df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Saturday' )])['Customer ID'].unique())
yellow_sunday_customers =  len((df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Sunday' )])['Customer ID'].unique())

print(yellow_mon_customers)
print(yellow_wedn_customers)
print(yellow_fri_customers)
print(yellow_satur_customers)
print(yellow_sunday_customers)
# Out:
# 21661
# 13751
# 16285
# 23131
# 22760

# %%
#Analyse number of customers based on days of week

pink_days_customers = [pink_mon_customers, pink_tues_customers, pink_wedn_customers, pink_thurs_customers, pink_fri_customers, pink_satur_customers, pink_sunday_customers]
yellow_days_customers = [yellow_mon_customers, yellow_tues_customers, yellow_wedn_customers, yellow_thurs_customers, yellow_fri_customers, yellow_satur_customers, yellow_sunday_customers]

names = ['Mon', 'Tues', 'Wednes', 'Thurs', 'Fri', 'Satur', 'Sun']
fig, ax = plt.subplots()    

ind = np.arange(len(pink_days_customers))  
ax.bar(ind, yellow_days_customers, color='orange', edgecolor='white', width=0.85, label = 'Yellow Cab')
ax.bar(ind, pink_days_customers, bottom=yellow_days_customers, color='blue', edgecolor='white', width=0.85, label = 'Pink Cab')
ax.set_xticks(ind, names)
ax.set_xlabel("Days")
ax.set_ylabel("No of cutomers")
ax.set_title('Daywise Customer Analyses')
for i, v in enumerate(yellow_days_customers):
    ax.text(i-.25,  
              v-10000, 
              yellow_days_customers[i], 
              fontsize=8)

for j, k in enumerate(pink_days_customers): 
    ax.text(j-.25,  
                2.4*k, 
                pink_days_customers[j], 
                fontsize=8)
plt.legend(loc = 'upper left', bbox_to_anchor=(0.3,1), ncol=1, title = 'Company')
plt.savefig('daywise_cus.png')
plt.show()

# %%
# Number of rides based on days of the week  for Pink Cab company

pink_mon_rides =  (df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Monday' )])['Transaction ID'].value_counts().sum()
pink_tues_rides =  (df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Tuesday' )])['Transaction ID'].value_counts().sum()
pink_wedn_rides =  (df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Wednesday' )])['Transaction ID'].value_counts().sum()
pink_thurs_rides =  (df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Thursday' )])['Transaction ID'].value_counts().sum()
pink_fri_rides =  (df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Friday' )])['Transaction ID'].value_counts().sum()
pink_satur_rides =  (df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Saturday' )])['Transaction ID'].value_counts().sum()
pink_sunday_rides =  (df[(df['Company'] == 'Pink Cab') & (df['Days'] == 'Sunday' )])['Transaction ID'].value_counts().sum()

print(pink_mon_rides)
print(pink_wedn_rides)
print(pink_satur_rides)
print(pink_sunday_rides)
# Out:
# 16475
# 7077
# 19249
# 18253

# %%
# Number of rides based on days of the week  for Yellow Cab company

yellow_mon_rides =  (df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Monday' )])['Transaction ID'].value_counts().sum()
yellow_tues_rides =  (df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Tuesday' )])['Transaction ID'].value_counts().sum()
yellow_wedn_rides =  (df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Wednesday' )])['Transaction ID'].value_counts().sum()
yellow_thurs_rides =  (df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Thursday' )])['Transaction ID'].value_counts().sum()
yellow_fri_rides =  (df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Friday' )])['Transaction ID'].value_counts().sum()
yellow_satur_rides =  (df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Saturday' )])['Transaction ID'].value_counts().sum()
yellow_sunday_rides =  (df[(df['Company'] == 'Yellow Cab') & (df['Days'] == 'Sunday' )])['Transaction ID'].value_counts().sum()

print(yellow_mon_rides)
print(yellow_wedn_rides)
print(yellow_fri_rides)
print(yellow_satur_rides)
print(yellow_sunday_rides)
# Out:
# 53835
# 22783
# 30198
# 62153
# 59981

# %%
# Daywise ride analyses based on days

pink_days_rides = [pink_mon_rides, pink_tues_rides, pink_wedn_rides, pink_thurs_rides, pink_fri_rides, pink_satur_rides, pink_sunday_rides]
yellow_days_rides = [yellow_mon_rides, yellow_tues_rides, yellow_wedn_rides, yellow_thurs_rides, yellow_fri_rides, yellow_satur_rides, yellow_sunday_rides]

names = ['Mon', 'Tues', 'Wednes', 'Thurs', 'Fri', 'Satur', 'Sun']
fig, ax = plt.subplots()    

ind = np.arange(len(pink_days_rides))  
ax.bar(ind, yellow_days_rides, color='orange', edgecolor='white', width=0.85, label = 'Yellow Cab')
ax.bar(ind, pink_days_rides, bottom=yellow_days_rides, color='blue', edgecolor='white', width=0.85, label = 'Pink Cab')
ax.set_xticks(ind, names)
ax.set_xlabel("Days")
ax.set_ylabel("No of rides")
ax.set_title('Daywise Ride Analyses')
for i, v in enumerate(yellow_days_rides):
    ax.text(i-.25,  
              v-10000, 
              yellow_days_rides[i], 
              fontsize=8)

for j, k in enumerate(pink_days_rides): 
    ax.text(j-.25,  
                3.5*k, 
                pink_days_rides[j], 
                fontsize=8)
plt.legend(loc = 'upper left', bbox_to_anchor=(0.3,1), ncol=1, title = 'Company')
plt.savefig('daywise_ride.png')
plt.show()

# %% [markdown]
# ## 12. Profit Forecasting for 2019

# %%
pink_y = [pink_2016_total, pink_2017_total]
yellow_y = [yellow_2016_total, yellow_2017_total]
x = [2016, 2017]
plt.figure(figsize=(10,8))
plt.plot(x, pink_y, label = 'Pink Cab')
plt.plot(x, yellow_y, label = 'Yellow Cab')
plt.plot([2016, 2017], [1388023.719, 1977169.122], 'o')
plt.plot([2016, 2017], [12326843.6012, 16337826.43], 'o')
plt.text(2015.90, 1570000, '1388024')
plt.text(2016.92, 2300000, '1977169')
plt.text(2015.90,13000000, '12326843')
plt.text(2016.92,16500000, '16337826')

plt.annotate(f'Profit in % = {round(profit_in_pink, 2)}', xy=(2016.50, 2100000), xytext=(2016.25,3500000),
                   arrowprops=dict(facecolor='black', shrink = 0.01))

plt.annotate(f'Profit in % = {round(profit_in_yellow, 2)}', xy=(2016.65, 14500000), xytext=(2016.45,11900000),
                   arrowprops=dict(facecolor='black', shrink = 0.01))

plt.title('Total profit by years for each company')
plt.xlabel('Years')
plt.ylabel('Profit')
plt.legend()
plt.savefig('forecasting_profit.png')
plt.show()
